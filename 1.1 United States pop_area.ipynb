# %%
import pandas as pd

# %% [markdown]
# # 미국의 state별 면적 당 인구수를 구해보자

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 1.1 population data
# - 지역, 연령대(total / under18), 데이터수집년도, 인구수를 보여주는 데이터

# %%
population = pd.read_csv("Data/state-population.csv", encoding = 'utf-8-sig')
population.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %% [markdown]
# ### 1.2 areas data
# - 각 state 별로 면적을 보여주는 데이터

# %%
areas = pd.read_csv("Data/state-areas.csv", encoding = 'utf-8-sig')
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %% [markdown]
# ### 1.3 abbrevs data
# - 각 state의 약어를 보여주는 데이터

# %%
abbrevs = pd.read_csv("Data/state-abbrevs.csv", encoding = 'utf-8-sig')
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 2.1.population data

# %%
pop = pd.read_csv("Data/state-population.csv", encoding = 'utf-8-sig')
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %% [markdown]
# #### 2.1.1. null 값 처리

# %%
pop.isnull().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# dtype: int64

# %% [markdown]
# population column에 NaN값이 있음을 알 수 있다.
# 그래서 population 열에서 NaN 값을 가지는 행을 가져와보면 다음과 같다.

# %%
pop[pop['population'].isnull()]
# Out:
#      state/region     ages  year  population
# 2448           PR  under18  1990         NaN
# 2449           PR    total  1990         NaN
# 2450           PR    total  1991         NaN
# 2451           PR  under18  1991         NaN
# 2452           PR    total  1993         NaN
# 2453           PR  under18  1993         NaN
# 2454           PR  under18  1992         NaN
# 2455           PR    total  1992         NaN
# 2456           PR  under18  1994         NaN
# 2457           PR    total  1994         NaN
# 2458           PR    total  1995         NaN
# 2459           PR  under18  1995         NaN
# 2460           PR  under18  1996         NaN
# 2461           PR    total  1996         NaN
# 2462           PR  under18  1998         NaN
# 2463           PR    total  1998         NaN
# 2464           PR    total  1997         NaN
# 2465           PR  under18  1997         NaN
# 2466           PR    total  1999         NaN
# 2467           PR  under18  1999         NaN

# %% [markdown]
# state/region 이 PR인 행에서 모든 NaN 값이 발생함을 알 수 있다.
# 그러면 이 NaN 값을 처리해줘야 하는데, 그 전에 PR의 정보를 알기 위해서 state/region 이 PR인 행에서 NaN이 아닌 데이터를 확인해보자.

# %%
PR = pop[pop['state/region']=='PR']
PR = PR[PR['population'].notnull()]

# %%
PR.head()
# Out:
#      state/region     ages  year  population
# 2468           PR    total  2000   3810605.0
# 2469           PR  under18  2000   1089063.0
# 2470           PR    total  2001   3818774.0
# 2471           PR  under18  2001   1077566.0
# 2472           PR    total  2002   3823701.0

# %%
PR.tail()
# Out:
#      state/region     ages  year  population
# 2491           PR  under18  2010    896945.0
# 2492           PR  under18  2011    869327.0
# 2493           PR    total  2011   3686580.0
# 2494           PR  under18  2012    841740.0
# 2495           PR    total  2012   3651545.0

# %% [markdown]
# 이를 보면 PR 지역은 2000년부터 집계가 시작되었음을 알 수 있다.
# 또한 위의 NaN데이터를 보면 1990~1999 까지는 NaN 값이고, 2000년부터는 중간에 끊긴 부분이 없기 때문에 PR에서는 그냥 NaN 값을 drop시키면 될것같다.

# %%
pop = pop.dropna()

# %%
pop.isnull().sum()
# Out:
# state/region    0
# ages            0
# year            0
# population      0
# dtype: int64

# %% [markdown]
# dropna 결과를 확인해보니 이제 NaN 값이 없는 것을 확인할 수 있다.
# 이제는 뒤에 있을 전처리 과정을 위해 열의 이름을 바꿔주자.
# abbrevs data 의 abbreviation 열에 지역의 약어가 들어가 있기 떄문에 population 데이터의 state/region 열을 맞춰주면 될것 같다.
# population 데이터의 열을 리스트로 받아오고, 그 리스트에 접근하는 방법으로 열의 이름을 바꿔주었다.

# %%
cols = pop.columns.to_list()
cols[0] = 'abbreviation'
pop.columns = cols
pop.columns
# Out:
# Index(['abbreviation', 'ages', 'year', 'population'], dtype='object')

# %% [markdown]
# NaN 값을 없애줬으니, 이제는 중복값이 있는지도 확인해보자.
# duplicated() 와 value_counts를 이용해보면 될것같다.

# %%
pop.duplicated().sum()
# Out:
# 0

# %%
pop.value_counts().max()
# Out:
# 1

# %% [markdown]
# 중복값이 없다는 결과를 확인할 수 있다.

# %% [markdown]
# #### 2.1.2.  total / under18 분류하기
# - 연령대별로 지표를 알아보기 위해 분류

# %%
pop_tot = pop[pop['ages'] == 'total']
pop_tot.head()
# Out:
#   abbreviation   ages  year  population
# 1           AL  total  2012   4817528.0
# 3           AL  total  2010   4785570.0
# 5           AL  total  2011   4801627.0
# 6           AL  total  2009   4757938.0
# 9           AL  total  2013   4833722.0

# %%
pop_18 = pop[pop['ages'] == 'under18']
pop_18.head()
# Out:
#   abbreviation     ages  year  population
# 0           AL  under18  2012   1117489.0
# 2           AL  under18  2010   1130966.0
# 4           AL  under18  2011   1125763.0
# 7           AL  under18  2009   1134192.0
# 8           AL  under18  2013   1111481.0

# %% [markdown]
# ### 2.2.areas Data

# %%
area = pd.read_csv("Data/state-areas.csv", encoding = 'utf-8-sig')
area.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
area.shape
# Out:
# (52, 2)

# %% [markdown]
# #### 2.2.1. null값/ 중복값 처리하기

# %%
area.isnull().sum()
# Out:
# state            0
# area (sq. mi)    0
# dtype: int64

# %%
area.duplicated().sum()
# Out:
# 0

# %% [markdown]
# NaN 값과 중복값 모두 없음을 확인할 수 있다. 기분이 좋다.

# %% [markdown]
# ### 2.3. abbreves data

# %%
abb = pd.read_csv("Data/state-abbrevs.csv", encoding = 'utf-8-sig')
abb.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
abb.shape
# Out:
# (51, 2)

# %% [markdown]
# #### 2.3.1. null값/ 중복값 처리하기

# %%
abb.isnull().sum()
# Out:
# state           0
# abbreviation    0
# dtype: int64

# %%
abb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# abbreves 데이터도 NaN 값과 중복값이 없는 깔끔한 데이터이다.

# %% [markdown]
# ## 3. area / abb 병합
# - area 데이터의 state를 약어로 나타내기 위해 둘을 병합하여 정리해준다.

# %%
area.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abb.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %% [markdown]
# 두 데이터에 공통으로 들어가있는 state 열을 기준으로 병합해주고, 모든 데이터를 가져오기 위해 outer join 해준다.
# 병합 후에 두 데이터 중 하나의 데이터에만 있는 정보는 NaN 값이 될 가능성이 있기 떄문에 null 값 유무도 확인해야한다.

# %%
area_abb = pd.merge(area, abb, on = 'state', how = 'outer')
area_abb.head()
# Out:
#         state  area (sq. mi) abbreviation
# 0     Alabama          52423           AL
# 1      Alaska         656425           AK
# 2     Arizona         114006           AZ
# 3    Arkansas          53182           AR
# 4  California         163707           CA

# %%
area_abb.isnull().sum()
# Out:
# state            0
# area (sq. mi)    0
# abbreviation     1
# dtype: int64

# %% [markdown]
# abbreviation 열에 NaN 값이 있다.
# 어디서 나온 건지 확인해보자.

# %%
area_abb[area_abb['abbreviation'].isnull()]
# Out:
#           state  area (sq. mi) abbreviation
# 51  Puerto Rico           3515          NaN

# %% [markdown]
# 확인 결과 Puetro Rico 의 약어가 정해지지 않았다.
# fillna() 함수를 통해 NaN 값을 PR로 채워주자.

# %%
area_abb = area_abb.fillna("PR")
area_abb[area_abb['state'] == 'Puerto Rico']
# Out:
#           state  area (sq. mi) abbreviation
# 51  Puerto Rico           3515           PR

# %% [markdown]
# ## 4.population과 병합

# %% [markdown]
# ### 4.1. pop_tot 과 병합

# %% [markdown]
# pop_tot 데이터와 df1 데이터에 공통으로 들어가있는 abbreviation 을 기준으로 병합하고, outer join 해주자.
# 이 경우도 NaN 값이 있는지 확인해야한다.

# %%
final_tot = pd.merge(pop_tot, area_abb, on = 'abbreviation', how = 'outer')
final_tot
# Out:
#      abbreviation   ages  year   population    state  area (sq. mi)
# 0              AL  total  2012    4817528.0  Alabama        52423.0
# 1              AL  total  2010    4785570.0  Alabama        52423.0
# 2              AL  total  2011    4801627.0  Alabama        52423.0
# 3              AL  total  2009    4757938.0  Alabama        52423.0
# 4              AL  total  2013    4833722.0  Alabama        52423.0
# ...           ...    ...   ...          ...      ...            ...
# 1257          USA  total  2013  316128839.0      NaN            NaN
# 1258          USA  total  2009  306771529.0      NaN            NaN
# 1259          USA  total  2010  309326295.0      NaN            NaN
# 1260          USA  total  2011  311582564.0      NaN            NaN
# 1261          USA  total  2012  313873685.0      NaN            NaN
#
# [1262 rows x 6 columns]

# %%
final_tot.isnull().sum()
# Out:
# abbreviation      0
# ages              0
# year              0
# population        0
# state            24
# area (sq. mi)    24
# dtype: int64

# %% [markdown]
# NaN 값이 있기 때문에 어디서 나온 값인지 확인하자.

# %%
final_tot[final_tot['state'].isnull()]
# Out:
#      abbreviation   ages  year   population state  area (sq. mi)
# 1238          USA  total  1990  249622814.0   NaN            NaN
# 1239          USA  total  1991  252980942.0   NaN            NaN
# 1240          USA  total  1992  256514231.0   NaN            NaN
# 1241          USA  total  1993  259918595.0   NaN            NaN
# 1242          USA  total  1994  263125826.0   NaN            NaN
# 1243          USA  total  1995  266278403.0   NaN            NaN
# 1244          USA  total  1996  269394291.0   NaN            NaN
# 1245          USA  total  1997  272646932.0   NaN            NaN
# 1246          USA  total  1998  275854116.0   NaN            NaN
# 1247          USA  total  2000  282162411.0   NaN            NaN
# 1248          USA  total  1999  279040181.0   NaN            NaN
# 1249          USA  total  2001  284968955.0   NaN            NaN
# 1250          USA  total  2002  287625193.0   NaN            NaN
# 1251          USA  total  2003  290107933.0   NaN            NaN
# 1252          USA  total  2004  292805298.0   NaN            NaN
# 1253          USA  total  2005  295516599.0   NaN            NaN
# 1254          USA  total  2006  298379912.0   NaN            NaN
# 1255          USA  total  2007  301231207.0   NaN            NaN
# 1256          USA  total  2008  304093966.0   NaN            NaN
# 1257          USA  total  2013  316128839.0   NaN            NaN
# 1258          USA  total  2009  306771529.0   NaN            NaN
# 1259          USA  total  2010  309326295.0   NaN            NaN
# 1260          USA  total  2011  311582564.0   NaN            NaN
# 1261          USA  total  2012  313873685.0   NaN            NaN

# %% [markdown]
# 확인 결과 USA에서 NaN 값이 나온 것을 확인할 수 있다.
# 하지만 우리가 구하려는 state 별 면적대비 인구수와는 관계가 없는 내용이므로 그냥 dropna()를 해서 없애주도록 하자.

# %%
final_tot = final_tot.dropna()
final_tot
# Out:
#      abbreviation   ages  year  population        state  area (sq. mi)
# 0              AL  total  2012   4817528.0      Alabama        52423.0
# 1              AL  total  2010   4785570.0      Alabama        52423.0
# 2              AL  total  2011   4801627.0      Alabama        52423.0
# 3              AL  total  2009   4757938.0      Alabama        52423.0
# 4              AL  total  2013   4833722.0      Alabama        52423.0
# ...           ...    ...   ...         ...          ...            ...
# 1233           PR  total  2013   3615086.0  Puerto Rico         3515.0
# 1234           PR  total  2009   3740410.0  Puerto Rico         3515.0
# 1235           PR  total  2010   3721208.0  Puerto Rico         3515.0
# 1236           PR  total  2011   3686580.0  Puerto Rico         3515.0
# 1237           PR  total  2012   3651545.0  Puerto Rico         3515.0
#
# [1238 rows x 6 columns]

# %%
final_tot.isnull().sum()
# Out:
# abbreviation     0
# ages             0
# year             0
# population       0
# state            0
# area (sq. mi)    0
# dtype: int64

# %%
final_tot.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 확인 결과 NaN 값과 중복값이 없는 깔끔한 데이터가 되었다.

# %% [markdown]
# ### 4.2. pop_18 과 병합

# %% [markdown]
# 이 경우 역시 USA 값이 NaN 이 나올 것이다.
# dropna() 를 해서 정리해주자.

# %%
final_18 = pd.merge(pop_18, area_abb, on = 'abbreviation', how = 'outer')
final_18
# Out:
#      abbreviation     ages  year  population    state  area (sq. mi)
# 0              AL  under18  2012   1117489.0  Alabama        52423.0
# 1              AL  under18  2010   1130966.0  Alabama        52423.0
# 2              AL  under18  2011   1125763.0  Alabama        52423.0
# 3              AL  under18  2009   1134192.0  Alabama        52423.0
# 4              AL  under18  2013   1111481.0  Alabama        52423.0
# ...           ...      ...   ...         ...      ...            ...
# 1257          USA  under18  2013  73585872.0      NaN            NaN
# 1258          USA  under18  2009  74134167.0      NaN            NaN
# 1259          USA  under18  2010  74119556.0      NaN            NaN
# 1260          USA  under18  2011  73902222.0      NaN            NaN
# 1261          USA  under18  2012  73708179.0      NaN            NaN
#
# [1262 rows x 6 columns]

# %%
final_18.isnull().sum()
# Out:
# abbreviation      0
# ages              0
# year              0
# population        0
# state            24
# area (sq. mi)    24
# dtype: int64

# %%
final_18 = final_18.dropna()
final_18
# Out:
#      abbreviation     ages  year  population        state  area (sq. mi)
# 0              AL  under18  2012   1117489.0      Alabama        52423.0
# 1              AL  under18  2010   1130966.0      Alabama        52423.0
# 2              AL  under18  2011   1125763.0      Alabama        52423.0
# 3              AL  under18  2009   1134192.0      Alabama        52423.0
# 4              AL  under18  2013   1111481.0      Alabama        52423.0
# ...           ...      ...   ...         ...          ...            ...
# 1233           PR  under18  2013    814068.0  Puerto Rico         3515.0
# 1234           PR  under18  2009    920794.0  Puerto Rico         3515.0
# 1235           PR  under18  2010    896945.0  Puerto Rico         3515.0
# 1236           PR  under18  2011    869327.0  Puerto Rico         3515.0
# 1237           PR  under18  2012    841740.0  Puerto Rico         3515.0
#
# [1238 rows x 6 columns]

# %% [markdown]
# ## 5. 면적 당 인구수
# - pop/area 라는 새로운 열을 만들어서 해당 내용을 넣어준다.

# %%
final_tot['pop/area'] = final_tot['population']/final_tot['area (sq. mi)']
final_tot
# Out:
# <ipython-input-43-817af97f792e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tot['pop/area'] = final_tot['population']/final_tot['area (sq. mi)']
#      abbreviation   ages  year  population        state  area (sq. mi)  \
# 0              AL  total  2012   4817528.0      Alabama        52423.0
# 1              AL  total  2010   4785570.0      Alabama        52423.0
# 2              AL  total  2011   4801627.0      Alabama        52423.0
# 3              AL  total  2009   4757938.0      Alabama        52423.0
# 4              AL  total  2013   4833722.0      Alabama        52423.0
# ...           ...    ...   ...         ...          ...            ...
# 1233           PR  total  2013   3615086.0  Puerto Rico         3515.0
# 1234           PR  total  2009   3740410.0  Puerto Rico         3515.0
# 1235           PR  total  2010   3721208.0  Puerto Rico         3515.0
# 1236           PR  total  2011   3686580.0  Puerto Rico         3515.0
# 1237           PR  total  2012   3651545.0  Puerto Rico         3515.0
#
#          pop/area
# 0       91.897221
# 1       91.287603
# 2       91.593900
# 3       90.760506
# 4       92.206131
# ...           ...
# 1233  1028.473969
# 1234  1064.128023
# 1235  1058.665149
# 1236  1048.813656
# 1237  1038.846373
#
# [1238 rows x 7 columns]

# %%
final_18['pop/area'] = final_18['population']/final_18['area (sq. mi)']
final_18
# Out:
# <ipython-input-60-b13c84d395ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_18['pop/area'] = final_18['population']/final_18['area (sq. mi)']
#      abbreviation     ages  year  population        state  area (sq. mi)  \
# 0              AL  under18  2012   1117489.0      Alabama        52423.0
# 1              AL  under18  2010   1130966.0      Alabama        52423.0
# 2              AL  under18  2011   1125763.0      Alabama        52423.0
# 3              AL  under18  2009   1134192.0      Alabama        52423.0
# 4              AL  under18  2013   1111481.0      Alabama        52423.0
# ...           ...      ...   ...         ...          ...            ...
# 1233           PR  under18  2013    814068.0  Puerto Rico         3515.0
# 1234           PR  under18  2009    920794.0  Puerto Rico         3515.0
# 1235           PR  under18  2010    896945.0  Puerto Rico         3515.0
# 1236           PR  under18  2011    869327.0  Puerto Rico         3515.0
# 1237           PR  under18  2012    841740.0  Puerto Rico         3515.0
#
#         pop/area
# 0      21.316769
# 1      21.573851
# 2      21.474601
# 3      21.635389
# 4      21.202163
# ...          ...
# 1233  231.598293
# 1234  261.961309
# 1235  255.176387
# 1236  247.319203
# 1237  239.470839
#
# [1238 rows x 7 columns]

# %% [markdown]
# 모든 전처리가 끝났다!!
# 이제부터는 필요한 부분만 가져와서 시각화를 하거나 분석하면 된다.

# %% [markdown]
# ## 6. 2013년 / total에서 면적 당 인구수
# - 면적당 인구수가 많은 순서대로 정렬해주자.

# %%
density_2013_tot = final_tot[final_tot['year']== 2013]
density_2013_tot = density_2013_tot.sort_values('pop/area', ascending=False)
density_2013_tot
# Out:
#      abbreviation   ages  year  population                 state  \
# 195            DC  total  2013    646449.0  District of Columbia
# 1233           PR  total  2013   3615086.0           Puerto Rico
# 723            NJ  total  2013   8899339.0            New Jersey
# 955            RI  total  2013   1051511.0          Rhode Island
# 147            CT  total  2013   3596080.0           Connecticut
# 524            MA  total  2013   6692824.0         Massachusetts
# 483            MD  total  2013   5928814.0              Maryland
# 187            DE  total  2013    925749.0              Delaware
# 772            NY  total  2013  19651127.0              New York
# 236            FL  total  2013  19552860.0               Florida
# 916            PA  total  2013  12773801.0          Pennsylvania
# 859            OH  total  2013  11570808.0                  Ohio
# 99             CA  total  2013  38332521.0            California
# 332            IL  total  2013  12882135.0              Illinois
# 1108           VA  total  2013   8260405.0              Virginia
# 811            NC  total  2013   9848060.0        North Carolina
# 339            IN  total  2013   6570902.0               Indiana
# 243            GA  total  2013   9992167.0               Georgia
# 1012           TN  total  2013   6495978.0             Tennessee
# 964            SC  total  2013   4774839.0        South Carolina
# 716            NH  total  2013   1323459.0         New Hampshire
# 284            HI  total  2013   1404054.0                Hawaii
# 428            KY  total  2013   4395295.0              Kentucky
# 531            MI  total  2013   9895622.0              Michigan
# 1051           TX  total  2013  26448193.0                 Texas
# 1147           WA  total  2013   6971406.0            Washington
# 4              AL  total  2013   4833722.0               Alabama
# 435            LA  total  2013   4625470.0             Louisiana
# 1195           WI  total  2013   5742713.0             Wisconsin
# 620            MO  total  2013   6044171.0              Missouri
# 1156           WV  total  2013   1854304.0         West Virginia
# 1099           VT  total  2013    626630.0               Vermont
# 572            MN  total  2013   5420380.0             Minnesota
# 579            MS  total  2013   2991207.0           Mississippi
# 51             AZ  total  2013   6626624.0               Arizona
# 92             AR  total  2013   2959373.0              Arkansas
# 868            OK  total  2013   3850568.0              Oklahoma
# 380            IA  total  2013   3090416.0                  Iowa
# 140            CO  total  2013   5268367.0              Colorado
# 907            OR  total  2013   3930065.0                Oregon
# 476            ME  total  2013   1328302.0                 Maine
# 387            KS  total  2013   2893957.0                Kansas
# 1060           UT  total  2013   2900872.0                  Utah
# 675            NV  total  2013   2790136.0                Nevada
# 668            NE  total  2013   1868516.0              Nebraska
# 291            ID  total  2013   1612136.0                 Idaho
# 763            NM  total  2013   2085287.0            New Mexico
# 1003           SD  total  2013    844877.0          South Dakota
# 820            ND  total  2013    723393.0          North Dakota
# 627            MT  total  2013   1015165.0               Montana
# 1204           WY  total  2013    582658.0               Wyoming
# 43             AK  total  2013    735132.0                Alaska
#
#       area (sq. mi)     pop/area
# 195            68.0  9506.602941
# 1233         3515.0  1028.473969
# 723          8722.0  1020.332378
# 955          1545.0   680.589644
# 147          5544.0   648.643579
# 524         10555.0   634.090384
# 483         12407.0   477.860401
# 187          1954.0   473.771238
# 772         54475.0   360.736613
# 236         65758.0   297.345722
# 916         46058.0   277.341634
# 859         44828.0   258.115642
# 99         163707.0   234.153219
# 332         57918.0   222.420232
# 1108        42769.0   193.140008
# 811         53821.0   182.978020
# 339         36420.0   180.420154
# 243         59441.0   168.102269
# 1012        42146.0   154.130356
# 964         32007.0   149.181085
# 716          9351.0   141.531280
# 284         10932.0   128.435236
# 428         40411.0   108.764817
# 531         96810.0   102.216940
# 1051       268601.0    98.466473
# 1147        71303.0    97.771566
# 4           52423.0    92.206131
# 435         51843.0    89.220724
# 1195        65503.0    87.670992
# 620         69709.0    86.705748
# 1156        24231.0    76.526103
# 1099         9615.0    65.172127
# 572         86943.0    62.344065
# 579         48434.0    61.758414
# 51         114006.0    58.125221
# 92          53182.0    55.646140
# 868         69903.0    55.084446
# 380         56276.0    54.915346
# 140        104100.0    50.608713
# 907         98386.0    39.945368
# 476         35387.0    37.536440
# 387         82282.0    35.171204
# 1060        84904.0    34.166494
# 675        110567.0    25.234799
# 668         77358.0    24.154140
# 291         83574.0    19.289923
# 763        121593.0    17.149729
# 1003        77121.0    10.955213
# 820         70704.0    10.231288
# 627        147046.0     6.903724
# 1204        97818.0     5.956552
# 43         656425.0     1.119903

# %%
density_2013_tot_top10 = density_2013_tot[['abbreviation', 'pop/area']][:10]
density_2013_tot_top10
# Out:
#      abbreviation     pop/area
# 195            DC  9506.602941
# 1233           PR  1028.473969
# 723            NJ  1020.332378
# 955            RI   680.589644
# 147            CT   648.643579
# 524            MA   634.090384
# 483            MD   477.860401
# 187            DE   473.771238
# 772            NY   360.736613
# 236            FL   297.345722
