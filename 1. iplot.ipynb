# %% [markdown]
# ## 1. iplot

# %%
# !pip install plotly chart_studio --upgrade
# !pip install cufflinks --upgrade

# %%
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected = True)

# %% [markdown]
# ### 1.1. 기본 형태 : dataframe.iplot(kind =‘그래프 종류’)
# - df.iplot(kind = ‘bar’) - bar 그래프 작성
# - df.iplot(kind = ‘bar’, barmode = ‘stack’) - 누적그래프 작성
# - df.iplot(kind = ‘bar’, barmode = ‘stack’, orientation = ‘h’) - 가로로 그래프 작성
# - df.iplot(kind = ‘scatter’) - line 그래프 작성
# - df.iplot(kind = ‘scatter’, mode = ‘lines + markers’) - 선/점 모두 나타냄
# - df.iplot(kind = ‘scatter’, fill = True) - lines 아랫부분을 채워줌
# - df.iplot(kind = ‘scatter’, xTitle = ‘ x title ’, yTitle = ‘ y title ’, title = ‘ title ‘) - 타이틀 설정

# %% [markdown]
# ### 1.2. 시리즈로 그래프 그리기
#
# - df [‘column’].iplot( kind = ‘그래프 종류' )

# %% [markdown]
# ### 1.3. 그래프 테마 가져오기
# - cf.getThemes( ) - 테마 가져옴
# - df.iplot(kind = ‘scatter’, theme =‘~’) - 그래프테마 설정

# %% [markdown]
# ![newplot%20%2812%29.png](attachment:newplot%20%2812%29.png)

# %% [markdown]
# ![newplot%20%2813%29.png](attachment:newplot%20%2813%29.png)

# %% [markdown]
# ![newplot%20%2814%29.png](attachment:newplot%20%2814%29.png)

# %% [markdown]
# ![newplot%20%2815%29.png](attachment:newplot%20%2815%29.png)

# %% [markdown]
# ![newplot%20%2816%29.png](attachment:newplot%20%2816%29.png)

# %% [markdown]
# ![newplot%20%2817%29.png](attachment:newplot%20%2817%29.png)

# %% [markdown]
# ![newplot%20%2818%29.png](attachment:newplot%20%2818%29.png)

# %% [markdown]
# ### 1.4. 레이아웃 만들기 - 딕셔너리
# - 그래프를 세밀하게 조정하는 데에 필요한 정보들
# - title : 그래프의 제목을 나타내는 딕셔너리 - 제목의 내용과 폰트(사이즈 / 글자색), x축 / y축 기준 제목의 위치를 지정함
# - plot_bgcolor : 그래프의 뒷배경 색깔 지정
# - xaxis / yaxis : x축,y축을 상세조정함
#  - showticklabels : tick을 보여줄것인지 여부를 결정
#  - dtick : tick의 간격을 지정
#  - title : 각 축의 제목, 사이즈, 글자색 지정

# %%
layout = {
    ‘title’ : 
        {‘text’ : "Iplot layout",
         ‘font’ : {‘size’ : 20, ‘color’ : 'b'},
         ‘x’ : 0.5, ‘y’: 0.9
        },
    
    ‘plot_bgcolor’ : 색상코드,
    
    ‘xaxis’ : {‘showticklabels’ : True / False, ‘dtick’ : 2,
                ‘title’ : {
                    ‘text’ : "x axis",
                    ‘font’ : {‘size’ : 15, ‘color’ : ~~}}
              }

    ‘yaxis’ : {‘showticklabels’ : True / False, dtick’ : 5,
                ‘title’ : {‘text’ : "y axis",
                ‘font’ : {‘size’ :15, ‘color’ : ~~}}
              }
    
    
df.iplot(kind = ‘scatter’, mode = ‘lines+markers’, layout = layout)

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-01-05%20222242.png](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-01-05%20222242.png)
